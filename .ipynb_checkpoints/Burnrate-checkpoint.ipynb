# %% [markdown]
# # Dados e Aprendizagem Automática
# ## Previsão eficiência do sono
#
#
# **Dataset:** .xlsx
#
# **Link** https://www.kaggle.com/datasets/vijaysubhashp/employee-burnout-prediction?rvi=1
#
# **Problema:** Prever eficiência do sono.
# ___
# **Features do Dataset:**
#
# ___
# **Grupo:**
# - João Paulo Machado Abreu - pg53928
# - João Pedro Dias Faria - pg53939
# - Ricardo Cardoso Sousa - pg54179
# - Rui Pedro Guise da Silva - pg54213

# %% [markdown]
# ## Importes e compreensão dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timezone

# %% [markdown]
# Ler excel

# %%
df = pd.read_excel('./datasets/grupo/Burnout.xlsx')
df
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No            2                  3.0
# 1                     Yes            1                  2.0
# 2                     Yes            2                  NaN
# 3                     Yes            1                  1.0
# 4                      No            3                  7.0
# ...                   ...          ...                  ...
# 22745                  No            1                  3.0
# 22746                 Yes            3                  6.0
# 22747                 Yes            3                  7.0
# 22748                  No            2                  5.0
# 22749                  No            3                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 0                       3.8       0.16
# 1                       5.0       0.36
# 2                       5.8       0.49
# 3                       2.6       0.20
# 4                       6.9       0.52
# ...                     ...        ...
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61
#
# [22750 rows x 9 columns]

# %% [markdown]
# Podemos verificar que este dataset é contem apenas 22750 entradas para 9 atributos.

# %%
df.shape
# Out:
# (22750, 9)

# %% [markdown]
# O dataset tem 4 atributos numéricos,
#
# É possivel identificar a preseça de valores nulos em:
# *  Resource Allocation
# *  Mental Fatigue Score
# *  Burn Rate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  datetime64[ns]
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# Para uma melhor visualização dos valores em falta:

# %%
df.isnull().sum()
# Out:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# dtype: int64

# %%
df.describe()
# Out:
#                      Date of Joining   Designation  Resource Allocation  \
# count                          22750  22750.000000         21369.000000
# mean   2008-07-01 09:28:05.274725120      2.178725             4.481398
# min              2008-01-01 00:00:00      0.000000             1.000000
# 25%              2008-04-01 00:00:00      1.000000             3.000000
# 50%              2008-07-02 00:00:00      2.000000             4.000000
# 75%              2008-09-30 00:00:00      3.000000             6.000000
# max              2008-12-31 00:00:00      5.000000            10.000000
# std                              NaN      1.135145             2.047211
#
#        Mental Fatigue Score     Burn Rate
# count          20633.000000  21626.000000
# mean               5.728188      0.452005
# min                0.000000      0.000000
# 25%                4.600000      0.310000
# 50%                5.900000      0.450000
# 75%                7.100000      0.590000
# max               10.000000      1.000000
# std                1.920839      0.198226

# %% [markdown]
# O objetivo de trabalhar com este dataset é identificar o burn rate, sendo a label um valor continuo compreendido entre 0 e 1.

# %% [markdown]
# ## Exploração e preparação de dados

# %% [markdown]
# ### Missing values

# %% [markdown]
# Para obter uma visualização gráfica dos missing values utilizamos o seguinte heatmap

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Função para preencher os valores nulos com 0.

# %%
def fill_with_zeros(data,columns):
    data = df
    
    data[columns] = data[columns].fillna(0)
    
    return data

# %%
def remove_lines(data,columns):
    data = df
    
    data.dropna(subset=columns,inplace=True)
    
    return data

# %%
def fill_with_mean(data,columns):
    data = df
    
    data[columns] = data[columns].fillna(data[columns].mean())
    
    return data

# %%
df=remove_lines(df,['Burn Rate','Resource Allocation'])

# %%
#df=fill_with_zeros(df,['Resource Allocation','Mental Fatigue Score'])

# %%
df=fill_with_mean(df,['Resource Allocation'])

# %%
sns.boxplot(x='Designation',y='Mental Fatigue Score',data=df,palette='winter')
# Out:
# <Axes: xlabel='Designation', ylabel='Mental Fatigue Score'>

# %%
medias = df.groupby('Designation')['Mental Fatigue Score'].mean()
print(medias)
# Out:
# Designation
# 0    2.637157
# 1    4.443171
# 2    5.672385
# 3    6.623577
# 4    7.735645
# 5    8.929022
# Name: Mental Fatigue Score, dtype: float64

# %%
def impute_mental(cols):
    Mental_Fatigue_Score = cols[0]
    Designation = cols[1]
    
    if pd.isnull(Mental_Fatigue_Score):

        if Designation == 1:
            return 4.564954

        elif Designation == 2:
            return 5.673261

        elif Designation == 3:
            return 6.541166
        
        elif Designation == 4:
            return 7.550271
        
        elif Designation == 5:
            return 8.591660
        
        else:
            return 2.924587

    else:
        return Mental_Fatigue_Score

# %%
df['Mental Fatigue Score'] = df[['Mental Fatigue Score','Designation']].apply(impute_mental,axis=1)

# %% [markdown]
# Podemos verificar então que todos os missing values foram tratados.

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### Duplicados

# %% [markdown]
# O data set não possui valores duplicados,portanto não foi necessário fazer nada a seu respeito.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Drop

# %% [markdown]
# Uma vez que a coluna Employee ID possui um valor diferente para todos os individuos decidimos removê-la,uma vez que em nada contribui para o treino do modelo.

# %%
df.drop(['Employee ID'], axis = 1, inplace = True)

# %% [markdown]
# ### Categoric data

# %%
'''
data_r3 = df.copy()

from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
lb_results = lb.fit_transform(data_r3['Gender'])
lb_results_df = pd.DataFrame(lb_results, columns=lb.classes_)

lb_results_df.head()
'''
# Out:
# "\ndata_r3 = df.copy()\n\nfrom sklearn.preprocessing import LabelBinarizer\n\nlb = LabelBinarizer()\nlb_results = lb.fit_transform(data_r3['Gender'])\nlb_results_df = pd.DataFrame(lb_results, columns=lb.classes_)\n\nlb_results_df.head()\n"

# %% [markdown]
# Gender One-Hot encoding

# %%
df_v1 = df.copy()
gender_mapper = {'Male':0, 'Female':1}
df_v1['Gender'] = df_v1['Gender'].replace(gender_mapper)
df_v1 = df_v1.join(pd.get_dummies(df_v1['Gender'], prefix='Gender').astype(int))
df_v1.rename(columns={'Gender_0':'Male','Gender_1':'Female'},inplace=True)
df_v1.drop(['Gender'], axis = 1, inplace = True)
df_v1.head()
# Out:
#   Date of Joining Company Type WFH Setup Available  Designation  \
# 0      2008-09-30      Service                  No            2
# 1      2008-11-30      Service                 Yes            1
# 3      2008-11-03      Service                 Yes            1
# 4      2008-07-24      Service                  No            3
# 5      2008-11-26      Product                 Yes            2
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate  Male  Female
# 0                  3.0                   3.8       0.16     0       1
# 1                  2.0                   5.0       0.36     1       0
# 3                  1.0                   2.6       0.20     1       0
# 4                  7.0                   6.9       0.52     0       1
# 5                  4.0                   3.6       0.29     1       0

# %% [markdown]
# WFH Setup Available One-Hot encoding

# %%
workplace_mapper = {'No':0, 'Yes':1}
df_v1['WFH Setup Available'] = df_v1['WFH Setup Available'].replace(workplace_mapper)
df_v1 = df_v1.join(pd.get_dummies(df_v1['WFH Setup Available'], prefix='WFH Setup Available').astype(int))
df_v1.rename(columns={'WFH Setup Available_0':'Office','WFH Setup Available_1':'Home'},inplace=True)
df_v1.drop(['WFH Setup Available'], axis = 1, inplace = True)
df_v1.head()
# Out:
#   Date of Joining Company Type  Designation  Resource Allocation  \
# 0      2008-09-30      Service            2                  3.0
# 1      2008-11-30      Service            1                  2.0
# 3      2008-11-03      Service            1                  1.0
# 4      2008-07-24      Service            3                  7.0
# 5      2008-11-26      Product            2                  4.0
#
#    Mental Fatigue Score  Burn Rate  Male  Female  Office  Home
# 0                   3.8       0.16     0       1       1     0
# 1                   5.0       0.36     1       0       0     1
# 3                   2.6       0.20     1       0       0     1
# 4                   6.9       0.52     0       1       1     0
# 5                   3.6       0.29     1       0       0     1

# %% [markdown]
# Company Type One-Hot encoding

# %%
df_v1['Company Type'].nunique()
# Out:
# 2

# %%
company_mapper = {'Service':0, 'Product':1}
df_v1['Company Type'] = df_v1['Company Type'].replace(company_mapper)
df_v1 = df_v1.join(pd.get_dummies(df_v1['Company Type'], prefix='Company Type').astype(int))
df_v1.rename(columns={'Company Type_0':'Service','Company Type_1':'Product'},inplace=True)
df_v1.drop(['Company Type'], axis = 1, inplace = True)
df_v1.head()
# Out:
#   Date of Joining  Designation  Resource Allocation  Mental Fatigue Score  \
# 0      2008-09-30            2                  3.0                   3.8
# 1      2008-11-30            1                  2.0                   5.0
# 3      2008-11-03            1                  1.0                   2.6
# 4      2008-07-24            3                  7.0                   6.9
# 5      2008-11-26            2                  4.0                   3.6
#
#    Burn Rate  Male  Female  Office  Home  Service  Product
# 0       0.16     0       1       1     0        1        0
# 1       0.36     1       0       0     1        1        0
# 3       0.20     1       0       0     1        1        0
# 4       0.52     0       1       1     0        1        0
# 5       0.29     1       0       0     1        0        1

# %% [markdown]
# ### Handling dates

# %%
df_v1['Date of Joining'].head()
# Out:
# 0   2008-09-30
# 1   2008-11-30
# 3   2008-11-03
# 4   2008-07-24
# 5   2008-11-26
# Name: Date of Joining, dtype: datetime64[ns]

# %% [markdown]
# Extrair dia,mês e ano da data,para colunas em separado

# %%
df_v1['year_of_joining'] = df_v1['Date of Joining'].dt.year
df_v1['month_of_joining'] = df_v1['Date of Joining'].dt.month
df_v1['day_of_joining'] = df_v1['Date of Joining'].dt.day

# %%
df_v1.nunique()
# Out:
# Date of Joining         366
# Designation               6
# Resource Allocation      10
# Mental Fatigue Score    107
# Burn Rate               101
# Male                      2
# Female                    2
# Office                    2
# Home                      2
# Service                   2
# Product                   2
# year_of_joining           1
# month_of_joining         12
# day_of_joining           31
# dtype: int64

# %% [markdown]
# Tal como fizemos na coluna dos ID's retiramos também a coluna year_of_joining

# %%
df_v1.drop(['Date of Joining','year_of_joining'], axis = 1, inplace = True)

# %% [markdown]
# ### Exploraty Data Analysis

# %% [markdown]
# Para analisar a corrrelação entre as variaveis geramos a seguinte matriz de correlação:

# %%
fig = plt.figure(figsize = (16,20))
incidents_corr = df_v1.corr(method = 'pearson')
sns.heatmap(incidents_corr, linecolor='black', linewidth=0.5,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Podemos constatar que existem relações fortes entre:
# - burn rate e designation
# - burn rate e Resource Allocation
# - burn rate e mental fatigue score

# %%
df_v1.drop(['month_of_joining','day_of_joining'], axis = 1, inplace = True)

# %% [markdown]
# A distribuição entre os individuos que trabalham em casa é ligeiramente superior aos que trabalham a partir de cas

# %%
sns.set_style('whitegrid')
sns.countplot(x='WFH Setup Available',data=df,palette='RdBu_r')
# Out:
# <Axes: xlabel='WFH Setup Available', ylabel='count'>

# %% [markdown]
# Para verificar a distribuição dos valores de burn rate utilizamos o seguinte histograma:

# %%
sns.histplot(df_v1['Burn Rate'],bins=15,color='darkgreen',kde=True)
# Out:
# <Axes: xlabel='Burn Rate', ylabel='Count'>

# %% [markdown]
# É de facil interpretação que a nossa label segue uma distribuição normal

# %%
fig,axs=plt.subplots(2,2,figsize=(12,10))
fig.suptitle('Boxplots de 2 variaveis')
sns.boxplot(data=df['Resource Allocation'],ax=axs[0,0])
axs[0,0].set_title('Resource Allocation')
sns.boxplot(data=df['Mental Fatigue Score'],ax=axs[0,1])
axs[0,1].set_title('Mental Fatigue Score')
sns.boxplot(data=df['Designation'],ax=axs[1,0])
axs[1,0].set_title('Designation')
# Out:
# Text(0.5, 1.0, 'Designation')

# %% [markdown]
# Para além da matriz de correlação criamos também o pairplot,e guardamos o resultado numa imagem

# %%
#pair_plot=sns.pairplot(df_v1)
#pair_plot.savefig('burnratepairplot.png')

# %% [markdown]
# Para vizualizar melhor as relações observadas entre determinadas variaveis no pairplot,procedemos à realização de alguns jointplots

# %% [markdown]
# A relação que mais chamou atenção foi entre a label burn rate e a feature mental fatigue score

# %%
sns.set_style('whitegrid')
sns.set_palette('Set2')
sns.jointplot(x='Mental Fatigue Score',y='Burn Rate',data=df_v1,kind="hex")

# %% [markdown]
# Outra relação obdervada também no joinplot como também na matriz de correlação é entre a target e a feature designation

# %%
sns.set_style('whitegrid')
sns.set_palette('coolwarm')
sns.jointplot(x='Designation',y='Burn Rate',data=df_v1)

# %% [markdown]
# ## Model conception (Model)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense#, Dropout, BatchNormalization
from scikeras.wrappers import KerasRegressor#, KerasClassifier
# Out:
# 2023-11-22 19:16:47.509830: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Dados de treino e de teste

# %% [markdown]
# Antes de treinar os modelos dividimos as features e a label em duas variaveis diferentes,sendo elas X e y,respetivamente

# %%
X = df_v1.drop(['Burn Rate'], axis=1)
y = df_v1['Burn Rate']

# %% [markdown]
# Dividimos então os dados em dados de treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2023)

# %% [markdown]
# De forma a verificar se os dados de teste estão balanceados de forma semelhante aos dados de treino
# Criamos os 2 seguintes diagramas

# %%
fig,axs=plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Boxplots de 2 variaveis')
sns.histplot(data=y_test,ax=axs[0], bins=15,kde=True)
axs[0].set_title('Teste')
sns.histplot(data=y_train,ax=axs[1], bins=15,kde=True)
axs[1].set_title('Treino')
# Out:
# Text(0.5, 1.0, 'Treino')

# %% [markdown]
# Concluimos então que ambos seguem uma distribuição normal,ou seja estão distribuidos de forma semelhante

# %% [markdown]
# ### Regressão linear

# %% [markdown]
# De seguida criamos a uma instância do LinearRegression e alpicamos aos dados de treino

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -0.08855846011265656

# %%
coeff_df=pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                       Coefficient
# Designation             -0.011653
# Resource Allocation      0.035824
# Mental Fatigue Score     0.070855
# Male                     0.001946
# Female                  -0.001946
# Office                   0.006811
# Home                    -0.006811
# Service                  0.000226
# Product                 -0.000226

# %% [markdown]
# Uma vez treinado o modelo aplicamo-lo então aos dados de teste para obter uma previsão

# %%
prediction = lm.predict(X_test)

# %% [markdown]
# Comparamos de seguida a previsão obtida com os dados de teste

# %%
plt.xlabel('Dados de teste (y_test)')
plt.ylabel('Previsões (predictions)')
plt.scatter(y_test,prediction)

# %%
print(f'MAE: {mean_absolute_error(y_test, prediction)}')
print(f'MSE: {mean_squared_error(y_test, prediction)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, prediction))}')
r2score = lm.score(X_test, y_test)
print(f'R-squared score: {r2score}')
# Out:
# MAE: 0.04871680148970023
# MSE: 0.003859127358745312
# RMSE: 0.062121875042092156
# R-squared score: 0.9011241206347202

# %% [markdown]
# ### SVR

# %%
param_grid={'C':[0.1,100,1000],'gamma':[1,0.01,0.0001],'kernel':['rbf']}

# %%
grid = GridSearchCV(SVR(random_state=2021),param_grid,refit=True,verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ..........C=0.1, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END ..........C=0.1, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END ..........C=0.1, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END ..........C=0.1, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END ..........C=0.1, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END .......C=0.1, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END ..........C=100, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END ..........C=100, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END ..........C=100, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END ..........C=100, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END ..........C=100, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END .......C=100, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END .......C=100, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END .......C=100, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END .......C=100, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END .......C=100, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END .........C=1000, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END .........C=1000, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END .........C=1000, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END .........C=1000, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END .........C=1000, gamma=1, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END ......C=1000, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END ......C=1000, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END ......C=1000, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END ......C=1000, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END ......C=1000, gamma=0.01, kernel=rbf;, score=nan total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.0001, kernel=rbf;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 grid.fit(X_train,y_train)
#
# File ~/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 45 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/rui/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/rui/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/rui/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/svm/_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "/home/rui/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/svm/_base.py", line 743, in _validate_targets
#     check_classification_targets(y)
#   File "/home/rui/miniconda3/envs/DAA/lib/python3.10/site-packages/sklearn/utils/multiclass.py", line 215, in check_classification_targets
#     raise ValueError(
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %% [markdown]
# ### Artificial Neural Network

# %%
'''
def build_model(activation='relu',learning_rate=0.01):
    model=Sequential()
    model.add(Dense(16,input_dim=5,activation=activation))
    model.add(Dense(8,activation=activation))
    model.add(Dense(1,activation=activation))
    
    model.compile(
        loss='mae',
        optimizer=tf.optimizers.Adam(learning_rate),
        metrics=['mae','mse'])
    return model   
'''
# Out:
# "\ndef build_model(activation='relu',learning_rate=0.01):\n    model=Sequential()\n    model.add(Dense(16,input_dim=5,activation=activation))\n    model.add(Dense(8,activation=activation))\n    model.add(Dense(1,activation=activation))\n    \n    model.compile(\n        loss='mae',\n        optimizer=tf.optimizers.Adam(learning_rate),\n        metrics=['mae','mse'])\n    return model   \n"
