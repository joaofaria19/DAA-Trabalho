# %% [markdown]
# # Dados e Aprendizagem Automática
# ## Pervisão de *burnout* em trabalhadores
#
#
# **Dataset:** .xlsx
#
# **Link** https://www.kaggle.com/datasets/vijaysubhashp/employee-burnout-prediction?rvi=1
#
# **Problema:** Prever o *burnout* em trabalhadores.
# ___
# **Features do Dataset:**
# * Employee ID - identificador do funcionário (employee).
# * Date of Joining - Data em que o funcionário começou a trabalhar.
# * Gender - Género do funcionário
# * Company Type - Tipo de empresa do funcionário.
# * WFH Setup Available - Indica se existem sistemas que permitem o trabalho a partir de casa.
# * Designation - Escalão do funiconário.
# * Resource Allocation - Número de horas de trabalho por dia.
# * Mental Fatigue Score - Nível de fadiga mental do funcionário.
# * Burn Rate - Taxa de *burn out* de um funcionário.
# ___
# **Grupo:**
# - João Paulo Machado Abreu - pg53928
# - João Pedro Dias Faria - pg53939
# - Ricardo Cardoso Sousa - pg54179
# - Rui Pedro Guise da Silva - pg54213

# %% [markdown]
# ## Importes e compreensão dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timezone

# %% [markdown]
# Leitura e Visualização do *dataset* (Burnout.xlsx).

# %%
#pip install openpyxl #instalação necessária para ler um excel

# %%
df = pd.read_excel('./datasets/grupo/Burnout.xlsx')
df
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No            2                  3.0
# 1                     Yes            1                  2.0
# 2                     Yes            2                  NaN
# 3                     Yes            1                  1.0
# 4                      No            3                  7.0
# ...                   ...          ...                  ...
# 22745                  No            1                  3.0
# 22746                 Yes            3                  6.0
# 22747                 Yes            3                  7.0
# 22748                  No            2                  5.0
# 22749                  No            3                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 0                       3.8       0.16
# 1                       5.0       0.36
# 2                       5.8       0.49
# 3                       2.6       0.20
# 4                       6.9       0.52
# ...                     ...        ...
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61
#
# [22750 rows x 9 columns]

# %% [markdown]
# Podemos verificar que este *dataset* contêm 22750 entradas e 9 atributos.

# %%
df.shape
# Out:
# (22750, 9)

# %% [markdown]
# O *dataset* possui 4 atributos numéricos,
#
# É possivel identificar a preseça de valores nulos em:
# *  *Resource Allocation*
# *  *Mental Fatigue Score*
# *  *Burn Rate*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  datetime64[ns]
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# Para uma melhor visualização dos valores em falta:

# %%
df.isnull().sum()
# Out:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# dtype: int64

# %%
df.describe()
# Out:
#                      Date of Joining   Designation  Resource Allocation  \
# count                          22750  22750.000000         21369.000000
# mean   2008-07-01 09:28:05.274725120      2.178725             4.481398
# min              2008-01-01 00:00:00      0.000000             1.000000
# 25%              2008-04-01 00:00:00      1.000000             3.000000
# 50%              2008-07-02 00:00:00      2.000000             4.000000
# 75%              2008-09-30 00:00:00      3.000000             6.000000
# max              2008-12-31 00:00:00      5.000000            10.000000
# std                              NaN      1.135145             2.047211
#
#        Mental Fatigue Score     Burn Rate
# count          20633.000000  21626.000000
# mean               5.728188      0.452005
# min                0.000000      0.000000
# 25%                4.600000      0.310000
# 50%                5.900000      0.450000
# 75%                7.100000      0.590000
# max               10.000000      1.000000
# std                1.920839      0.198226

# %% [markdown]
# O objetivo de trabalhar com este *dataset* é identificar o *burn rate*, sendo a label um valor continuo compreendido entre 0 e 1.

# %% [markdown]
# ## Exploração e preparação de dados

# %% [markdown]
# ### 1.Missing values

# %% [markdown]
# Começamos o nosso processo de preparação de dados pela exploração dos *missing values* do nosso *dataset*. Para obter uma visualização gráfica dos *missing values* utilizamos o seguinte heatmap.

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Função para preencher os valores nulos com 0.

# %%
def fill_with_zeros(data,columns):
    data = df
    
    data[columns] = data[columns].fillna(0)
    
    return data

# %%
def remove_lines(data,columns):
    data = df
    
    data.dropna(subset=columns,inplace=True)
    
    return data

# %%
def fill_with_mean(data,columns):
    data = df
    
    data[columns] = data[columns].fillna(data[columns].mean())
    
    return data

# %%
df=remove_lines(df,['Burn Rate','Resource Allocation'])

# %%
#df=fill_with_zeros(df,['Resource Allocation','Mental Fatigue Score'])

# %%
#df=fill_with_mean(df,['Resource Allocation'])

# %%
sns.boxplot(x='Designation',y='Mental Fatigue Score',data=df,palette='winter')
# Out:
# <Axes: xlabel='Designation', ylabel='Mental Fatigue Score'>

# %%
medias = df.groupby('Designation')['Mental Fatigue Score'].mean()
print(medias)
# Out:
# Designation
# 0    2.637157
# 1    4.443171
# 2    5.672385
# 3    6.623577
# 4    7.735645
# 5    8.929022
# Name: Mental Fatigue Score, dtype: float64

# %%
def impute_mental(cols):
    Mental_Fatigue_Score = cols[0]
    Designation = cols[1]
    
    if pd.isnull(Mental_Fatigue_Score):

        if Designation == 1:
            return 4.564954

        elif Designation == 2:
            return 5.673261

        elif Designation == 3:
            return 6.541166
        
        elif Designation == 4:
            return 7.550271
        
        elif Designation == 5:
            return 8.591660
        
        else:
            return 2.924587

    else:
        return Mental_Fatigue_Score

# %%
df['Mental Fatigue Score'] = df[['Mental Fatigue Score','Designation']].apply(impute_mental,axis=1)

# %% [markdown]
# Podemos verificar então que todos os missing values foram tratados.

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# #### Duplicados

# %% [markdown]
# O *dataset* não possui valores duplicados, portanto não foi necessário fazer nada a seu respeito.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Drop

# %% [markdown]
# Uma vez que a coluna *Employee ID* possui um valor diferente para todos os individuos decidimos removê-la, uma vez que em nada contribui para o treino do modelo.

# %%
df.drop(['Employee ID'], axis = 1, inplace = True)

# %% [markdown]
# ### 2.Dados Categóricos

# %% [markdown]
# Em seguida, começamos por tratar os nossos dados categóricos, de todas as técnicas de *encoding* decidimos utilizar a técnica de *One-Hot encoding* em todos os atributos categóricos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20348 entries, 0 to 22749
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date of Joining       20348 non-null  datetime64[ns]
#  1   Gender                20348 non-null  object
#  2   Company Type          20348 non-null  object
#  3   WFH Setup Available   20348 non-null  object
#  4   Designation           20348 non-null  int64
#  5   Resource Allocation   20348 non-null  float64
#  6   Mental Fatigue Score  20348 non-null  float64
#  7   Burn Rate             20348 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 1.4+ MB

# %%
'''
data_r3 = df.copy()

from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
lb_results = lb.fit_transform(data_r3['Gender'])
lb_results_df = pd.DataFrame(lb_results, columns=lb.classes_)

lb_results_df.head()
'''
# Out:
# "\ndata_r3 = df.copy()\n\nfrom sklearn.preprocessing import LabelBinarizer\n\nlb = LabelBinarizer()\nlb_results = lb.fit_transform(data_r3['Gender'])\nlb_results_df = pd.DataFrame(lb_results, columns=lb.classes_)\n\nlb_results_df.head()\n"

# %% [markdown]
# - Gender One-Hot encoding

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    10691
# Male       9657
# Name: count, dtype: int64

# %%
df_v1 = df.copy()
gender_mapper = {'Male':0, 'Female':1}
df_v1['Gender'] = df_v1['Gender'].replace(gender_mapper)
df_v1 = df_v1.join(pd.get_dummies(df_v1['Gender'], prefix='Gender').astype(int))
df_v1.rename(columns={'Gender_0':'Male','Gender_1':'Female'},inplace=True)
df_v1.drop(['Gender'], axis = 1, inplace = True)
df_v1.head()
# Out:
#   Date of Joining Company Type WFH Setup Available  Designation  \
# 0      2008-09-30      Service                  No            2
# 1      2008-11-30      Service                 Yes            1
# 3      2008-11-03      Service                 Yes            1
# 4      2008-07-24      Service                  No            3
# 5      2008-11-26      Product                 Yes            2
#
#    Resource Allocation  Mental Fatigue Score  Burn Rate  Male  Female
# 0                  3.0                   3.8       0.16     0       1
# 1                  2.0                   5.0       0.36     1       0
# 3                  1.0                   2.6       0.20     1       0
# 4                  7.0                   6.9       0.52     0       1
# 5                  4.0                   3.6       0.29     1       0

# %% [markdown]
# - WFH Setup Available One-Hot encoding

# %%
df_v1['WFH Setup Available'].value_counts()
# Out:
# WFH Setup Available
# Yes    11000
# No      9348
# Name: count, dtype: int64

# %%
workplace_mapper = {'No':0, 'Yes':1}
df_v1['WFH Setup Available'] = df_v1['WFH Setup Available'].replace(workplace_mapper)
df_v1 = df_v1.join(pd.get_dummies(df_v1['WFH Setup Available'], prefix='WFH Setup Available').astype(int))
df_v1.rename(columns={'WFH Setup Available_0':'Office','WFH Setup Available_1':'Home'},inplace=True)
df_v1.drop(['WFH Setup Available'], axis = 1, inplace = True)
df_v1.head()
# Out:
#   Date of Joining Company Type  Designation  Resource Allocation  \
# 0      2008-09-30      Service            2                  3.0
# 1      2008-11-30      Service            1                  2.0
# 3      2008-11-03      Service            1                  1.0
# 4      2008-07-24      Service            3                  7.0
# 5      2008-11-26      Product            2                  4.0
#
#    Mental Fatigue Score  Burn Rate  Male  Female  Office  Home
# 0                   3.8       0.16     0       1       1     0
# 1                   5.0       0.36     1       0       0     1
# 3                   2.6       0.20     1       0       0     1
# 4                   6.9       0.52     0       1       1     0
# 5                   3.6       0.29     1       0       0     1

# %% [markdown]
# - Company Type One-Hot encoding

# %%
df_v1['Company Type'].nunique()
# Out:
# 2

# %%
df_v1['Company Type'].value_counts()
# Out:
# Company Type
# Service    13316
# Product     7032
# Name: count, dtype: int64

# %%
company_mapper = {'Service':0, 'Product':1}
df_v1['Company Type'] = df_v1['Company Type'].replace(company_mapper)
df_v1 = df_v1.join(pd.get_dummies(df_v1['Company Type'], prefix='Company Type').astype(int))
df_v1.rename(columns={'Company Type_0':'Service','Company Type_1':'Product'},inplace=True)
df_v1.drop(['Company Type'], axis = 1, inplace = True)
df_v1.head()
# Out:
#   Date of Joining  Designation  Resource Allocation  Mental Fatigue Score  \
# 0      2008-09-30            2                  3.0                   3.8
# 1      2008-11-30            1                  2.0                   5.0
# 3      2008-11-03            1                  1.0                   2.6
# 4      2008-07-24            3                  7.0                   6.9
# 5      2008-11-26            2                  4.0                   3.6
#
#    Burn Rate  Male  Female  Office  Home  Service  Product
# 0       0.16     0       1       1     0        1        0
# 1       0.36     1       0       0     1        1        0
# 3       0.20     1       0       0     1        1        0
# 4       0.52     0       1       1     0        1        0
# 5       0.29     1       0       0     1        0        1

# %% [markdown]
# ### 3.Handling dates

# %% [markdown]
# Para o tratamento das datas decidimos extrair o dia, mês e ano da data, para colunas em separado.

# %%
df_v1['Date of Joining'].head()
# Out:
# 0   2008-09-30
# 1   2008-11-30
# 3   2008-11-03
# 4   2008-07-24
# 5   2008-11-26
# Name: Date of Joining, dtype: datetime64[ns]

# %%
df_v1['year_of_joining'] = df_v1['Date of Joining'].dt.year
df_v1['month_of_joining'] = df_v1['Date of Joining'].dt.month
df_v1['day_of_joining'] = df_v1['Date of Joining'].dt.day

# %% [markdown]
# Como podemos constatar, a coluna referente ao ano de junção do funcionário exibe apenas um valor (2008).

# %%
df_v1.nunique()
# Out:
# Date of Joining         366
# Designation               6
# Resource Allocation      10
# Mental Fatigue Score    107
# Burn Rate               101
# Male                      2
# Female                    2
# Office                    2
# Home                      2
# Service                   2
# Product                   2
# year_of_joining           1
# month_of_joining         12
# day_of_joining           31
# dtype: int64

# %% [markdown]
# Assim, retiramos também a coluna *year_of_joining* igualmente ao que já tinhamos feito anteriormente com a coluna *Employee ID*

# %%
df_v1.drop(['Date of Joining','year_of_joining'], axis = 1, inplace = True)

# %% [markdown]
# ## Análise Exploratória de Dados

# %% [markdown]
# Começamos por analisar a correlação entre os vários atributos, geramos, assim, a seguinte matriz de correlação:

# %%
fig = plt.figure(figsize = (16,20))
incidents_corr = df_v1.corr(method = 'pearson')
sns.heatmap(incidents_corr, linecolor='black', linewidth=0.5,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Podemos constatar que existem relações fortes entre os seguintes atributos:
# - *burn rate* e *designation*
# - *burn rate* e *Resource Allocation*
# - *burn rate* e *mental fatigue score*
#
# Entretanto, notamos que os atributos seguintes têm uma correlação próxima de zero com os demais atributos:
# - *month_of_joining*
# - *day_of_joining*
#
# Devido à fraca correlação destes atributos, optamos por removê-los, igualmente ao que havia acontecido com o atributo *Employee ID*.

# %%
df_v1.drop(['month_of_joining','day_of_joining'], axis = 1, inplace = True)

# %%
df_v1.drop(['Product','Service'], axis = 1, inplace = True)

# %% [markdown]
# Há uma pequena diferença na distribuição entre aqueles que possuem sistemas que possibilitam o trabalho remoto em comparação com aqueles que não têm esses sistemas.

# %%
sns.set_style('whitegrid')
sns.countplot(x='WFH Setup Available',data=df,palette='RdBu_r')
# Out:
# <Axes: xlabel='WFH Setup Available', ylabel='count'>

# %% [markdown]
# Para verificar a distribuição dos valores de *burn rate* utilizamos o seguinte histograma:

# %%
sns.histplot(df_v1['Burn Rate'],bins=15,color='darkgreen',kde=True)
# Out:
# <Axes: xlabel='Burn Rate', ylabel='Count'>

# %% [markdown]
# Facilmente interpretamos que a nossa label segue uma distribuição normal.
# Podemos observar que a nossa métrica de assimetria (Skewness) exibe um valor muito próximo de zero, indicando uma distribuição próxima à normal para o nosso gráfico.

# %%
print(f"Skewness: {df['Burn Rate'].skew()}")
# Out:
# Skewness: 0.04262589219088042

# %% [markdown]
# Para cada variável contínua, decidimos utilizar um boxplot para identificar os outliers e destacar a dispersão dos daods de forma clara e rápida.

# %%
fig,axs=plt.subplots(2,2,figsize=(12,10))
fig.suptitle('Boxplots de 2 variaveis')
sns.boxplot(data=df['Resource Allocation'],ax=axs[0,0])
axs[0,0].set_title('Resource Allocation')
sns.boxplot(data=df['Mental Fatigue Score'],ax=axs[0,1])
axs[0,1].set_title('Mental Fatigue Score')
sns.boxplot(data=df['Designation'],ax=axs[1,0])
axs[1,0].set_title('Designation')
# Out:
# Text(0.5, 1.0, 'Designation')

# %% [markdown]
# Para além da matriz de correlação criamos também o pairplot, e guardamos o resultado numa imagem (burnratepairplot.png).

# %%
#pair_plot=sns.pairplot(df_v1)
#pair_plot.savefig('burnratepairplot.png')

# %% [markdown]
# Para uma melhor visualização das relações observadas entre determinadas variaveis no pairplot, procedemos à realização de alguns jointplots, permitindo uma análise mais detalhada e focada nos padrões identificados.

# %% [markdown]
# A relação que mais chamou atenção foi entre a label *burn rate* e a *feature mental fatigue score*.

# %%
sns.set_style('whitegrid')
sns.set_palette('Set2')
sns.jointplot(x='Mental Fatigue Score',y='Burn Rate',data=df_v1,kind="hex")

# %% [markdown]
# Uma outra relação identificada tanto no jointplot quanto na matriz de correlação é aquela existente entre a variável alvo (*burn rate*) e a *feature* de *designation*, indicando uma possível associação ou influência mútua entre elas.

# %%
sns.set_style('whitegrid')
sns.set_palette('coolwarm')
sns.jointplot(x='Designation',y='Burn Rate',data=df_v1)

# %% [markdown]
# ## Conceção do Modelo

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC,SVR

# %%
from sklearn.model_selection import GridSearchCV, KFold, train_test_split

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense#, Dropout, BatchNormalization
from scikeras.wrappers import KerasRegressor#, KerasClassifier
# Out:
# 2024-01-09 15:06:07.884534: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn import metrics

# %%
from sklearn.ensemble import GradientBoostingClassifier, VotingClassifier, BaggingClassifier, StackingClassifier
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# ### Dados de treino e de teste

# %% [markdown]
# Antes de treinar os modelos dividimos as **features** e a **label** em duas variaveis diferentes, sendo elas X e y, respetivamente

# %%
X = df_v1.drop(['Burn Rate'], axis=1)
y = df_v1['Burn Rate']

# %% [markdown]
# Dividimos então os dados em dados de treino e teste utilizando uma técnica de Hold-out Validation.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2023)

# %% [markdown]
# De forma, a verificar se os dados de teste estão balanceados de forma semelhante aos dados de treino criamos os dois seguintes diagramas:

# %%
fig,axs=plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Boxplots de 2 variaveis')
sns.histplot(data=y_test,ax=axs[0], bins=15,kde=True)
axs[0].set_title('Teste')
sns.histplot(data=y_train,ax=axs[1], bins=15,kde=True)
axs[1].set_title('Treino')
# Out:
# Text(0.5, 1.0, 'Treino')

# %% [markdown]
# Concluimos então que ambos seguem uma distribuição normal,ou seja, estão distribuidos de forma semelhante.

# %% [markdown]
# ### Criação e Treino de Modelos

# %% [markdown]
# Em seguida, instanciamos o modelo **LinearRegression** e o aplicamos o mesmo aos dados de treino.

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -0.08849513389221464

# %% [markdown]
# Podemos vericar que:
#   - Mantendo todos os outros atributos fixos, um aumento de 1 unidade no atributo  *Designation* está associado a uma diminuição de 0.011653 no atributo *Burn Rate*
#   - Mantendo todos os outros atributos fixos, um aumento de 1 unidade no atributo *Resource Allocation* está associado a um aumento de 0.035824 no atributo *Burn Rate*
#   - Mantendo todos os outros atributos fixos, um aumento de 1 unidade no atributo *Mental Fatigue Score* está associado a um aumento de 0.070855 no atributo *Burn Rate*

# %%
coeff_df=pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                       Coefficient
# Designation             -0.011650
# Resource Allocation      0.035825
# Mental Fatigue Score     0.070854
# Male                     0.001943
# Female                  -0.001943
# Office                   0.006810
# Home                    -0.006810

# %% [markdown]
# Uma vez treinado o modelo aplicamo-lo então aos dados de teste para obter uma previsão

# %%
prediction_lm = lm.predict(X_test)

# %% [markdown]
# Comparamos de seguida a previsão obtida com os dados de teste

# %%
plt.xlabel('Dados de teste (y_test)')
plt.ylabel('Previsões (predictions)')
plt.scatter(y_test,prediction_lm)

# %%
print(f'MAE: {mean_absolute_error(y_test, prediction_lm)}')
print(f'MSE: {mean_squared_error(y_test, prediction_lm)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, prediction_lm))}')
r2score = lm.score(X_test, y_test)
print(f'R-squared score: {r2score}')
# Out:
# MAE: 0.04872399285439895
# MSE: 0.0038600687723920513
# RMSE: 0.062129451730979016
# R-squared score: 0.9011000003884794

# %% [markdown]
# * MAE: 0.044891505395085185
# * MSE: 0.002991739365860408
# * RMSE: 0.054696794840835124
# * R-squared score: 0.9256166750779647

# %%
sns.displot((y_test-prediction_lm), bins=28, kde=True)
# Out:
# /home/rui/miniconda3/envs/DAA/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### SVR

# %%
svr = GridSearchCV(
    SVR(kernel="rbf"),
    param_grid={"C": [400,500,600], "gamma":[1,0.01,0.0001]},refit=True,verbose=3,scoring='neg_mean_absolute_error'
)

# %%
svr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ...................C=400, gamma=1;, score=-0.055 total time=  53.6s
# [CV 2/5] END ...................C=400, gamma=1;, score=-0.054 total time=  50.7s
# [CV 3/5] END ...................C=400, gamma=1;, score=-0.055 total time=  56.2s
# [CV 4/5] END ...................C=400, gamma=1;, score=-0.055 total time=  56.0s
# [CV 5/5] END ...................C=400, gamma=1;, score=-0.056 total time=  54.6s
# [CV 1/5] END ................C=400, gamma=0.01;, score=-0.050 total time=  13.1s
# [CV 2/5] END ................C=400, gamma=0.01;, score=-0.052 total time=  13.4s
# [CV 3/5] END ................C=400, gamma=0.01;, score=-0.051 total time=  12.5s
# [CV 4/5] END ................C=400, gamma=0.01;, score=-0.051 total time=  14.4s
# [CV 5/5] END ................C=400, gamma=0.01;, score=-0.053 total time=  12.5s
# [CV 1/5] END ..............C=400, gamma=0.0001;, score=-0.050 total time=   3.0s
# [CV 2/5] END ..............C=400, gamma=0.0001;, score=-0.050 total time=   2.9s
# [CV 3/5] END ..............C=400, gamma=0.0001;, score=-0.050 total time=   3.3s
# [CV 4/5] END ..............C=400, gamma=0.0001;, score=-0.051 total time=   3.1s
# [CV 5/5] END ..............C=400, gamma=0.0001;, score=-0.052 total time=   2.7s
# [CV 1/5] END ...................C=500, gamma=1;, score=-0.055 total time= 1.0min
# [CV 2/5] END ...................C=500, gamma=1;, score=-0.054 total time=  59.5s
# [CV 3/5] END ...................C=500, gamma=1;, score=-0.056 total time= 1.1min
# [CV 4/5] END ...................C=500, gamma=1;, score=-0.055 total time= 1.1min
# [CV 5/5] END ...................C=500, gamma=1;, score=-0.056 total time= 1.1min
# [CV 1/5] END ................C=500, gamma=0.01;, score=-0.050 total time=  16.3s
# [CV 2/5] END ................C=500, gamma=0.01;, score=-0.052 total time=  14.6s
# [CV 3/5] END ................C=500, gamma=0.01;, score=-0.051 total time=  15.3s
# [CV 4/5] END ................C=500, gamma=0.01;, score=-0.052 total time=  14.9s
# [CV 5/5] END ................C=500, gamma=0.01;, score=-0.053 total time=  15.4s
# [CV 1/5] END ..............C=500, gamma=0.0001;, score=-0.050 total time=   2.8s
# [CV 2/5] END ..............C=500, gamma=0.0001;, score=-0.050 total time=   3.1s
# [CV 3/5] END ..............C=500, gamma=0.0001;, score=-0.050 total time=   3.4s
# [CV 4/5] END ..............C=500, gamma=0.0001;, score=-0.051 total time=   2.9s
# [CV 5/5] END ..............C=500, gamma=0.0001;, score=-0.052 total time=   3.1s
# [CV 1/5] END ...................C=600, gamma=1;, score=-0.055 total time= 1.2min
# [CV 2/5] END ...................C=600, gamma=1;, score=-0.054 total time= 1.1min
# [CV 3/5] END ...................C=600, gamma=1;, score=-0.056 total time= 1.2min
# [CV 4/5] END ...................C=600, gamma=1;, score=-0.055 total time= 1.3min
# [CV 5/5] END ...................C=600, gamma=1;, score=-0.056 total time= 1.2min
# [CV 1/5] END ................C=600, gamma=0.01;, score=-0.050 total time=  16.5s
# [CV 2/5] END ................C=600, gamma=0.01;, score=-0.052 total time=  15.5s
# [CV 3/5] END ................C=600, gamma=0.01;, score=-0.051 total time=  17.5s
# [CV 4/5] END ................C=600, gamma=0.01;, score=-0.052 total time=  20.2s
# [CV 5/5] END ................C=600, gamma=0.01;, score=-0.053 total time=  18.1s
# [CV 1/5] END ..............C=600, gamma=0.0001;, score=-0.050 total time=   3.4s
# [CV 2/5] END ..............C=600, gamma=0.0001;, score=-0.050 total time=   3.8s
# [CV 3/5] END ..............C=600, gamma=0.0001;, score=-0.050 total time=   4.1s
# [CV 4/5] END ..............C=600, gamma=0.0001;, score=-0.051 total time=   3.6s
# [CV 5/5] END ..............C=600, gamma=0.0001;, score=-0.052 total time=   3.5s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [400, 500, 600], 'gamma': [1, 0.01, 0.0001]},
#              scoring='neg_mean_absolute_error', verbose=3)

# %%
best_model = svr.best_estimator_
best_model
# Out:
# SVR(C=400, gamma=0.0001)

# %%
prediction_svr = svr.predict(X_test)

# %%
plt.xlabel('Dados de teste (y_test)')
plt.ylabel('Previsões (predictions)')
plt.scatter(y_test,prediction_svr)

# %%
print(f'MAE: {mean_absolute_error(y_test, prediction_svr)}')
print(f'MSE: {mean_squared_error(y_test, prediction_svr)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, prediction_svr))}')
r2score = lm.score(X_test, y_test)
print(f'R-squared score: {r2score}')
# Out:
# MAE: 0.04954229400349311
# MSE: 0.0039086508165031226
# RMSE: 0.06251920358180454
# R-squared score: 0.9011000003884794

# %% [markdown]
# ### Artificial Neural Network

# %%
y=y.to_frame()

# %%
scaler_X = MinMaxScaler(feature_range=(0,1)).fit(X)
X_scaled = pd.DataFrame(scaler_X.transform(X[X.columns]),columns=X.columns)
scaler_y = MinMaxScaler(feature_range=(0,1)).fit(y)
y_scaled = pd.DataFrame(scaler_y.transform(y[y.columns]),columns=y.columns)

# %%
X_train_s,X_test_s,y_train_s,y_test_s = train_test_split(X_scaled,y_scaled,test_size=0.2,random_state=2021)

# %%
def build_model(activation='relu',learning_rate=0.01):
    model=Sequential()
    model.add(Dense(16,input_dim=7,activation=activation))
    model.add(Dense(9,activation=activation))
    model.add(Dense(1,activation=activation))
    
    model.compile(
        loss='mae',
        optimizer=tf.optimizers.Adam(learning_rate),
        metrics=['mae','mse'])
    return model

# %%
optimizer=['SGD','RMSprop','Adagrad']
activation=['sigmoid','relu']
param_grid =dict(optimizer=optimizer)

# %%
kf = KFold(n_splits=5,shuffle=True,random_state=2021)

# %%
model = KerasRegressor(model=build_model,batch_size=64,validation_split=0.2,epochs=80)

# %%
grid_search = GridSearchCV(estimator=model,param_grid=param_grid,cv=kf,scoring='neg_mean_absolute_error',refit='True',verbose=1)

# %%
grid_search.fit(X_train_s,y_train_s)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# 2024-01-09 15:20:12.793092: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/80
# 163/163 [==============================] - 3s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 2/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 3/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 4/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 5/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 6/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 7/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 8/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 9/80
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 10/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 11/80
# 163/163 [==============================] - 1s 7ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 12/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 13/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 14/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 15/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 16/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 17/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 18/80
# 163/163 [==============================] - 3s 17ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 19/80
# 163/163 [==============================] - 3s 15ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 20/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 21/80
# 163/163 [==============================] - 3s 17ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 22/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 23/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 24/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 25/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 26/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 27/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 28/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 29/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 30/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 31/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 32/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 33/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 34/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 35/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 36/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 37/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 38/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 39/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 40/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 41/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 42/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 43/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 44/80
# 163/163 [==============================] - 3s 17ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 45/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 46/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 47/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 48/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 49/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 50/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 51/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 52/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 53/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 54/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 55/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 56/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 57/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 58/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 59/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 60/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 61/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 62/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 63/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 64/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 65/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 66/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 67/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 68/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 69/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 70/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 71/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 72/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 73/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 74/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 75/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 76/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 77/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 78/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 79/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# Epoch 80/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.4514 - mae: 0.4514 - mse: 0.2432 - val_loss: 0.4561 - val_mae: 0.4561 - val_mse: 0.2464
# 51/51 [==============================] - 0s 6ms/step
# Epoch 1/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0825 - mae: 0.0825 - mse: 0.0163 - val_loss: 0.0527 - val_mae: 0.0527 - val_mse: 0.0045
# Epoch 2/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0528 - mae: 0.0528 - mse: 0.0045 - val_loss: 0.0516 - val_mae: 0.0516 - val_mse: 0.0043
# Epoch 3/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0515 - mae: 0.0515 - mse: 0.0044 - val_loss: 0.0574 - val_mae: 0.0574 - val_mse: 0.0054
# Epoch 4/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0515 - mae: 0.0515 - mse: 0.0044 - val_loss: 0.0513 - val_mae: 0.0513 - val_mse: 0.0043
# Epoch 5/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0507 - mae: 0.0507 - mse: 0.0042 - val_loss: 0.0529 - val_mae: 0.0529 - val_mse: 0.0045
# Epoch 6/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0510 - mae: 0.0510 - mse: 0.0043 - val_loss: 0.0514 - val_mae: 0.0514 - val_mse: 0.0043
# Epoch 7/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0041
# Epoch 8/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0538 - val_mae: 0.0538 - val_mse: 0.0047
# Epoch 9/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0506 - mae: 0.0506 - mse: 0.0042 - val_loss: 0.0519 - val_mae: 0.0519 - val_mse: 0.0044
# Epoch 10/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0514 - val_mae: 0.0514 - val_mse: 0.0043
# Epoch 11/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 12/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0040
# Epoch 13/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 14/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 15/80
# 163/163 [==============================] - 3s 17ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 16/80
# 163/163 [==============================] - 3s 17ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0041 - val_loss: 0.0518 - val_mae: 0.0518 - val_mse: 0.0044
# Epoch 17/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0042
# Epoch 18/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0506 - mae: 0.0506 - mse: 0.0042 - val_loss: 0.0523 - val_mae: 0.0523 - val_mse: 0.0045
# Epoch 19/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0042 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 20/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 21/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 22/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 23/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0532 - val_mae: 0.0532 - val_mse: 0.0046
# Epoch 24/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0040 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0041
# Epoch 25/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0041
# Epoch 26/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0549 - val_mae: 0.0549 - val_mse: 0.0049
# Epoch 27/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0040
# Epoch 28/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0510 - val_mae: 0.0510 - val_mse: 0.0042
# Epoch 29/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0040
# Epoch 30/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 31/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0041 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0041
# Epoch 32/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0040 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 33/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0042
# Epoch 34/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0508 - mae: 0.0508 - mse: 0.0042 - val_loss: 0.0511 - val_mae: 0.0511 - val_mse: 0.0043
# Epoch 35/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0508 - mae: 0.0508 - mse: 0.0043 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 36/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0042
# Epoch 37/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 38/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 39/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 40/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0513 - val_mae: 0.0513 - val_mse: 0.0043
# Epoch 41/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0042
# Epoch 42/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0042
# Epoch 43/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 44/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 45/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0511 - val_mae: 0.0511 - val_mse: 0.0043
# Epoch 46/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0040 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0042
# Epoch 47/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.0489 - mae: 0.0489 - mse: 0.0039 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 48/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0533 - val_mae: 0.0533 - val_mse: 0.0046
# Epoch 49/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0519 - val_mae: 0.0519 - val_mse: 0.0044
# Epoch 50/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 51/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 52/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 53/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0579 - val_mae: 0.0579 - val_mse: 0.0054
# Epoch 54/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 55/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0043
# Epoch 56/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0040
# Epoch 57/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 58/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0491 - val_mae: 0.0491 - val_mse: 0.0039
# Epoch 59/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 60/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0521 - val_mae: 0.0521 - val_mse: 0.0044
# Epoch 61/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 62/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0043
# Epoch 63/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0039
# Epoch 64/80
# 163/163 [==============================] - 3s 15ms/step - loss: 0.0487 - mae: 0.0487 - mse: 0.0039 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 65/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0041 - val_loss: 0.0540 - val_mae: 0.0540 - val_mse: 0.0047
# Epoch 66/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0040 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0041
# Epoch 67/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0559 - val_mae: 0.0559 - val_mse: 0.0051
# Epoch 68/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0042
# Epoch 69/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0040 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0039
# Epoch 70/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 71/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0039
# Epoch 72/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0507 - val_mae: 0.0507 - val_mse: 0.0042
# Epoch 73/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0491 - val_mae: 0.0491 - val_mse: 0.0039
# Epoch 74/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0041
# Epoch 75/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0488 - val_mae: 0.0488 - val_mse: 0.0039
# Epoch 76/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0488 - mae: 0.0488 - mse: 0.0039 - val_loss: 0.0491 - val_mae: 0.0491 - val_mse: 0.0039
# Epoch 77/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0041
# Epoch 78/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0040 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0040
# Epoch 79/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0040
# Epoch 80/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0039
# 51/51 [==============================] - 0s 5ms/step
# Epoch 1/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0152 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 2/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0511 - mae: 0.0511 - mse: 0.0043 - val_loss: 0.0598 - val_mae: 0.0598 - val_mse: 0.0057
# Epoch 3/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 4/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0512 - val_mae: 0.0512 - val_mse: 0.0043
# Epoch 5/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0506 - mae: 0.0506 - mse: 0.0043 - val_loss: 0.0529 - val_mae: 0.0529 - val_mse: 0.0045
# Epoch 6/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0549 - val_mae: 0.0549 - val_mse: 0.0048
# Epoch 7/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0532 - val_mae: 0.0532 - val_mse: 0.0046
# Epoch 8/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0043 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 9/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0043 - val_loss: 0.0545 - val_mae: 0.0545 - val_mse: 0.0048
# Epoch 10/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 11/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 12/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 13/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0512 - val_mae: 0.0512 - val_mse: 0.0043
# Epoch 14/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0529 - val_mae: 0.0529 - val_mse: 0.0045
# Epoch 15/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 16/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0510 - val_mae: 0.0510 - val_mse: 0.0042
# Epoch 17/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0042 - val_loss: 0.0611 - val_mae: 0.0611 - val_mse: 0.0058
# Epoch 18/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0510 - mae: 0.0510 - mse: 0.0043 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 19/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 20/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0508 - mae: 0.0508 - mse: 0.0043 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 21/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0512 - val_mae: 0.0512 - val_mse: 0.0043
# Epoch 22/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0040
# Epoch 23/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 24/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0510 - val_mae: 0.0510 - val_mse: 0.0043
# Epoch 25/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0042
# Epoch 26/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0513 - val_mae: 0.0513 - val_mse: 0.0042
# Epoch 27/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 28/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 29/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0041
# Epoch 30/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 31/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0557 - val_mae: 0.0557 - val_mse: 0.0050
# Epoch 32/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 33/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0041
# Epoch 34/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0508 - mae: 0.0508 - mse: 0.0043 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 35/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0511 - val_mae: 0.0511 - val_mse: 0.0043
# Epoch 36/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0524 - val_mae: 0.0524 - val_mse: 0.0044
# Epoch 37/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0516 - val_mae: 0.0516 - val_mse: 0.0043
# Epoch 38/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0042
# Epoch 39/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0040
# Epoch 40/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0040
# Epoch 41/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0521 - val_mae: 0.0521 - val_mse: 0.0044
# Epoch 42/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 43/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 44/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 45/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0041
# Epoch 46/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0042 - val_loss: 0.0511 - val_mae: 0.0511 - val_mse: 0.0042
# Epoch 47/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0042 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0041
# Epoch 48/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0041
# Epoch 49/80
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0524 - val_mae: 0.0524 - val_mse: 0.0044
# Epoch 50/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0523 - val_mae: 0.0523 - val_mse: 0.0044
# Epoch 51/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 52/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 53/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0041
# Epoch 54/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0520 - val_mae: 0.0520 - val_mse: 0.0044
# Epoch 55/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 56/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 57/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0542 - val_mae: 0.0542 - val_mse: 0.0049
# Epoch 58/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 59/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0516 - val_mae: 0.0516 - val_mse: 0.0043
# Epoch 60/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0505 - val_mae: 0.0505 - val_mse: 0.0041
# Epoch 61/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 62/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 63/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0040
# Epoch 64/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0041
# Epoch 65/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 66/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0510 - val_mae: 0.0510 - val_mse: 0.0042
# Epoch 67/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 68/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0543 - val_mae: 0.0543 - val_mse: 0.0048
# Epoch 69/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 70/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0524 - val_mae: 0.0524 - val_mse: 0.0044
# Epoch 71/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0042
# Epoch 72/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0518 - val_mae: 0.0518 - val_mse: 0.0043
# Epoch 73/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0489 - mae: 0.0489 - mse: 0.0040 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 74/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 75/80
# 163/163 [==============================] - 2s 14ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0512 - val_mae: 0.0512 - val_mse: 0.0043
# Epoch 76/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 77/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0520 - val_mae: 0.0520 - val_mse: 0.0044
# Epoch 78/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0040
# Epoch 79/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 80/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# 51/51 [==============================] - 0s 4ms/step
# Epoch 1/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0762 - mae: 0.0762 - mse: 0.0157 - val_loss: 0.0529 - val_mae: 0.0529 - val_mse: 0.0045
# Epoch 2/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0523 - mae: 0.0523 - mse: 0.0045 - val_loss: 0.0586 - val_mae: 0.0586 - val_mse: 0.0055
# Epoch 3/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0523 - mae: 0.0523 - mse: 0.0045 - val_loss: 0.0533 - val_mae: 0.0533 - val_mse: 0.0046
# Epoch 4/80
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0526 - val_mae: 0.0526 - val_mse: 0.0045
# Epoch 5/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0510 - mae: 0.0510 - mse: 0.0043 - val_loss: 0.0518 - val_mae: 0.0518 - val_mse: 0.0044
# Epoch 6/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0519 - mae: 0.0519 - mse: 0.0045 - val_loss: 0.0549 - val_mae: 0.0549 - val_mse: 0.0049
# Epoch 7/80
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 8/80
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0514 - mae: 0.0514 - mse: 0.0044 - val_loss: 0.0516 - val_mae: 0.0516 - val_mse: 0.0044
# Epoch 9/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0508 - mae: 0.0508 - mse: 0.0043 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 10/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0042
# Epoch 11/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0538 - val_mae: 0.0538 - val_mse: 0.0047
# Epoch 12/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0041
# Epoch 13/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0042 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 14/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 15/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 16/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0559 - val_mae: 0.0559 - val_mse: 0.0051
# Epoch 17/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 18/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.0512 - mae: 0.0512 - mse: 0.0043 - val_loss: 0.0546 - val_mae: 0.0546 - val_mse: 0.0048
# Epoch 19/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 20/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0513 - mae: 0.0513 - mse: 0.0044 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 21/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0039
# Epoch 22/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 23/80
# 163/163 [==============================] - 2s 13ms/step - loss: 0.0507 - mae: 0.0507 - mse: 0.0043 - val_loss: 0.0559 - val_mae: 0.0559 - val_mse: 0.0050
# Epoch 24/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0511 - mae: 0.0511 - mse: 0.0043 - val_loss: 0.0524 - val_mae: 0.0524 - val_mse: 0.0044
# Epoch 25/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0042
# Epoch 26/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 27/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 28/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 29/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0040
# Epoch 30/80
# 163/163 [==============================] - 2s 15ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0040
# Epoch 31/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 32/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0527 - val_mae: 0.0527 - val_mse: 0.0045
# Epoch 33/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 34/80
# 163/163 [==============================] - 3s 16ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0551 - val_mae: 0.0551 - val_mse: 0.0049
# Epoch 35/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 36/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0594 - val_mae: 0.0594 - val_mse: 0.0057
# Epoch 37/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 38/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0515 - val_mae: 0.0515 - val_mse: 0.0043
# Epoch 39/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 40/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0491 - val_mae: 0.0491 - val_mse: 0.0040
# Epoch 41/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 42/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0505 - val_mae: 0.0505 - val_mse: 0.0042
# Epoch 43/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0043
# Epoch 44/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0510 - mae: 0.0510 - mse: 0.0043 - val_loss: 0.0532 - val_mae: 0.0532 - val_mse: 0.0046
# Epoch 45/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 46/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0041
# Epoch 47/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0526 - val_mae: 0.0526 - val_mse: 0.0045
# ...
# Epoch 67/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0520 - val_mae: 0.0520 - val_mse: 0.0044
# Epoch 68/80
# 163/163 [==============================] - 2s 12ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0487 - val_mae: 0.0487 - val_mse: 0.0039
# Epoch 69/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 70/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0043
# Epoch 71/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0039
# Epoch 72/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0488 - val_mae: 0.0488 - val_mse: 0.0039
# Epoch 73/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0043
# Epoch 74/80
# 163/163 [==============================] - 2s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0042 - val_loss: 0.0547 - val_mae: 0.0547 - val_mse: 0.0049
# Epoch 75/80
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0513 - val_mae: 0.0513 - val_mse: 0.0043
# Epoch 76/80
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0488 - val_mae: 0.0488 - val_mse: 0.0039
# Epoch 77/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0486 - val_mae: 0.0486 - val_mse: 0.0039
# Epoch 78/80
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0488 - val_mae: 0.0488 - val_mse: 0.0039
# Epoch 79/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0546 - val_mae: 0.0546 - val_mse: 0.0048
# Epoch 80/80
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0042 - val_loss: 0.0517 - val_mae: 0.0517 - val_mse: 0.0044
# 51/51 [==============================] - 0s 4ms/step
# Epoch 1/80
# 204/204 [==============================] - 3s 11ms/step - loss: 0.0610 - mae: 0.0610 - mse: 0.0066 - val_loss: 0.0521 - val_mae: 0.0521 - val_mse: 0.0045
# Epoch 2/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0511 - mae: 0.0511 - mse: 0.0043 - val_loss: 0.0517 - val_mae: 0.0517 - val_mse: 0.0044
# Epoch 3/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0506 - mae: 0.0506 - mse: 0.0043 - val_loss: 0.0531 - val_mae: 0.0531 - val_mse: 0.0047
# Epoch 4/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0516 - mae: 0.0516 - mse: 0.0044 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 5/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0508 - mae: 0.0508 - mse: 0.0043 - val_loss: 0.0510 - val_mae: 0.0510 - val_mse: 0.0042
# Epoch 6/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0587 - val_mae: 0.0587 - val_mse: 0.0055
# Epoch 7/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0510 - mae: 0.0510 - mse: 0.0043 - val_loss: 0.0545 - val_mae: 0.0545 - val_mse: 0.0049
# Epoch 8/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0516 - val_mae: 0.0516 - val_mse: 0.0043
# Epoch 9/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0510 - mae: 0.0510 - mse: 0.0043 - val_loss: 0.0505 - val_mae: 0.0505 - val_mse: 0.0041
# Epoch 10/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0509 - mae: 0.0509 - mse: 0.0043 - val_loss: 0.0507 - val_mae: 0.0507 - val_mse: 0.0042
# Epoch 11/80
# 204/204 [==============================] - 2s 7ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0042
# Epoch 12/80
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0614 - val_mae: 0.0614 - val_mse: 0.0060
# Epoch 13/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0517 - val_mae: 0.0517 - val_mse: 0.0043
# Epoch 14/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0041
# Epoch 15/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0515 - val_mae: 0.0515 - val_mse: 0.0043
# Epoch 16/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0507 - mae: 0.0507 - mse: 0.0043 - val_loss: 0.0539 - val_mae: 0.0539 - val_mse: 0.0048
# Epoch 17/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 18/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0040
# Epoch 19/80
# 204/204 [==============================] - 3s 12ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0532 - val_mae: 0.0532 - val_mse: 0.0046
# Epoch 20/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 21/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 22/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0042 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0040
# Epoch 23/80
# 204/204 [==============================] - 1s 7ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0491 - val_mae: 0.0491 - val_mse: 0.0039
# Epoch 24/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0523 - val_mae: 0.0523 - val_mse: 0.0044
# Epoch 25/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0041
# Epoch 26/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0517 - val_mae: 0.0517 - val_mse: 0.0043
# Epoch 27/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 28/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0531 - val_mae: 0.0531 - val_mse: 0.0047
# Epoch 29/80
# 204/204 [==============================] - 1s 6ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0039
# Epoch 30/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 31/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0041
# Epoch 32/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0042
# Epoch 33/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0517 - val_mae: 0.0517 - val_mse: 0.0043
# Epoch 34/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0522 - val_mae: 0.0522 - val_mse: 0.0044
# Epoch 35/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0509 - val_mae: 0.0509 - val_mse: 0.0043
# Epoch 36/80
# 204/204 [==============================] - 3s 13ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0039
# Epoch 37/80
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 38/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0508 - val_mae: 0.0508 - val_mse: 0.0042
# Epoch 39/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 40/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0497 - val_mae: 0.0497 - val_mse: 0.0040
# Epoch 41/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0507 - val_mae: 0.0507 - val_mse: 0.0041
# Epoch 42/80
# 204/204 [==============================] - 1s 7ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0041 - val_loss: 0.0528 - val_mae: 0.0528 - val_mse: 0.0045
# Epoch 43/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0515 - val_mae: 0.0515 - val_mse: 0.0043
# Epoch 44/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0040
# Epoch 45/80
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0507 - mae: 0.0507 - mse: 0.0043 - val_loss: 0.0503 - val_mae: 0.0503 - val_mse: 0.0041
# Epoch 46/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 47/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 48/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 49/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 50/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 51/80
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0523 - val_mae: 0.0523 - val_mse: 0.0045
# Epoch 52/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0499 - val_mae: 0.0499 - val_mse: 0.0041
# Epoch 53/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0496 - val_mae: 0.0496 - val_mse: 0.0040
# Epoch 54/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0521 - val_mae: 0.0521 - val_mse: 0.0044
# Epoch 55/80
# 204/204 [==============================] - 3s 13ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 56/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0491 - val_mae: 0.0491 - val_mse: 0.0040
# Epoch 57/80
# 204/204 [==============================] - 2s 8ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0498 - val_mae: 0.0498 - val_mse: 0.0040
# Epoch 58/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0504 - val_mae: 0.0504 - val_mse: 0.0042
# Epoch 59/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0041
# Epoch 60/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0500 - val_mae: 0.0500 - val_mse: 0.0040
# Epoch 61/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0040
# Epoch 62/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0502 - val_mae: 0.0502 - val_mse: 0.0041
# Epoch 63/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0505 - val_mae: 0.0505 - val_mse: 0.0042
# Epoch 64/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0552 - val_mae: 0.0552 - val_mse: 0.0050
# Epoch 65/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0039
# Epoch 66/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0040
# Epoch 67/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 68/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0492 - mae: 0.0492 - mse: 0.0040 - val_loss: 0.0512 - val_mae: 0.0512 - val_mse: 0.0043
# Epoch 69/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0502 - mae: 0.0502 - mse: 0.0042 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 70/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0494 - mae: 0.0494 - mse: 0.0041 - val_loss: 0.0515 - val_mae: 0.0515 - val_mse: 0.0043
# Epoch 71/80
# 204/204 [==============================] - 2s 12ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0494 - val_mae: 0.0494 - val_mse: 0.0041
# Epoch 72/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 73/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0497 - mae: 0.0497 - mse: 0.0041 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 74/80
# 204/204 [==============================] - 3s 13ms/step - loss: 0.0490 - mae: 0.0490 - mse: 0.0040 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 75/80
# 204/204 [==============================] - 2s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0539 - val_mae: 0.0539 - val_mse: 0.0047
# Epoch 76/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0042
# Epoch 77/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0491 - mae: 0.0491 - mse: 0.0040 - val_loss: 0.0495 - val_mae: 0.0495 - val_mse: 0.0040
# Epoch 78/80
# 204/204 [==============================] - 2s 10ms/step - loss: 0.0493 - mae: 0.0493 - mse: 0.0040 - val_loss: 0.0520 - val_mae: 0.0520 - val_mse: 0.0044
# Epoch 79/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0495 - mae: 0.0495 - mse: 0.0041 - val_loss: 0.0547 - val_mae: 0.0547 - val_mse: 0.0049
# Epoch 80/80
# 204/204 [==============================] - 2s 9ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0492 - val_mae: 0.0492 - val_mse: 0.0039
# GridSearchCV(cv=KFold(n_splits=5, random_state=2021, shuffle=True),
#              estimator=KerasRegressor(batch_size=64, epochs=80, model=<function build_model at 0x7f8def0cbe20>, validation_split=0.2),
#              param_grid={'optimizer': ['SGD', 'RMSprop', 'Adagrad']},
#              refit='True', scoring='neg_mean_absolute_error', verbose=1)

# %%
print("Best: %f using %s" % (grid_search.best_score_,grid_search.best_params_))
# Out:
# Best: -0.130294 using {'optimizer': 'SGD'}

# %%
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']

# %%
for mean,stdev,param in zip(means,stds,params):
    print("%f (%f) with: %r" % (mean,stdev,param))
# Out:
# -0.130294 (0.162250) with: {'optimizer': 'SGD'}
# -0.131099 (0.163246) with: {'optimizer': 'RMSprop'}
# -0.211573 (0.196506) with: {'optimizer': 'Adagrad'}

# %%
best_mlp_model = grid_search.best_estimator_
print(best_mlp_model)
# Out:
# KerasRegressor(
# 	model=<function build_model at 0x7f8def0cbe20>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=SGD
# 	loss=None
# 	metrics=None
# 	batch_size=64
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.2
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=80
# )

# %%
best_mlp_model.fit(X_train_s,y_train_s,epochs=20,validation_data=(X_test_s,y_test_s),verbose=1)
# Out:
# Epoch 1/20
# 255/255 [==============================] - 3s 10ms/step - loss: 0.0725 - mae: 0.0725 - mse: 0.0111 - val_loss: 0.0510 - val_mae: 0.0510 - val_mse: 0.0042
# Epoch 2/20
# 255/255 [==============================] - 2s 8ms/step - loss: 0.0518 - mae: 0.0518 - mse: 0.0044 - val_loss: 0.0547 - val_mae: 0.0547 - val_mse: 0.0047
# Epoch 3/20
# 255/255 [==============================] - 2s 6ms/step - loss: 0.0517 - mae: 0.0517 - mse: 0.0044 - val_loss: 0.0506 - val_mae: 0.0506 - val_mse: 0.0041
# Epoch 4/20
# 255/255 [==============================] - 2s 7ms/step - loss: 0.0515 - mae: 0.0515 - mse: 0.0044 - val_loss: 0.0487 - val_mae: 0.0487 - val_mse: 0.0038
# Epoch 5/20
# 255/255 [==============================] - 2s 7ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0564 - val_mae: 0.0564 - val_mse: 0.0052
# Epoch 6/20
# 255/255 [==============================] - 3s 11ms/step - loss: 0.0513 - mae: 0.0513 - mse: 0.0043 - val_loss: 0.0590 - val_mae: 0.0590 - val_mse: 0.0054
# Epoch 7/20
# 255/255 [==============================] - 3s 10ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0501 - val_mae: 0.0501 - val_mse: 0.0040
# Epoch 8/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0501 - mae: 0.0501 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0039
# Epoch 9/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0504 - mae: 0.0504 - mse: 0.0042 - val_loss: 0.0493 - val_mae: 0.0493 - val_mse: 0.0040
# Epoch 10/20
# 255/255 [==============================] - 3s 10ms/step - loss: 0.0505 - mae: 0.0505 - mse: 0.0042 - val_loss: 0.0549 - val_mae: 0.0549 - val_mse: 0.0049
# Epoch 11/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0522 - val_mae: 0.0522 - val_mse: 0.0045
# Epoch 12/20
# 255/255 [==============================] - 3s 12ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0488 - val_mae: 0.0488 - val_mse: 0.0039
# Epoch 13/20
# 255/255 [==============================] - 3s 11ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0479 - val_mae: 0.0479 - val_mse: 0.0037
# Epoch 14/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0479 - val_mae: 0.0479 - val_mse: 0.0037
# Epoch 15/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0592 - val_mae: 0.0592 - val_mse: 0.0057
# Epoch 16/20
# 255/255 [==============================] - 3s 11ms/step - loss: 0.0499 - mae: 0.0499 - mse: 0.0041 - val_loss: 0.0477 - val_mae: 0.0477 - val_mse: 0.0037
# Epoch 17/20
# 255/255 [==============================] - 3s 12ms/step - loss: 0.0503 - mae: 0.0503 - mse: 0.0042 - val_loss: 0.0478 - val_mae: 0.0478 - val_mse: 0.0037
# Epoch 18/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0500 - mae: 0.0500 - mse: 0.0041 - val_loss: 0.0480 - val_mae: 0.0480 - val_mse: 0.0037
# Epoch 19/20
# 255/255 [==============================] - 2s 7ms/step - loss: 0.0498 - mae: 0.0498 - mse: 0.0041 - val_loss: 0.0486 - val_mae: 0.0486 - val_mse: 0.0038
# Epoch 20/20
# 255/255 [==============================] - 2s 9ms/step - loss: 0.0496 - mae: 0.0496 - mse: 0.0041 - val_loss: 0.0490 - val_mae: 0.0490 - val_mse: 0.0038
# KerasRegressor(
# 	model=<function build_model at 0x7f8def0cbe20>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=SGD
# 	loss=None
# 	metrics=None
# 	batch_size=64
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.2
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=80
# )

# %%
plt.plot(best_mlp_model.history_['loss'])
plt.plot(best_mlp_model.history_['val_loss'])
plt.title('model performance')
plt.ylabel('loss values')
plt.xlabel('epoch')
plt.legend(['train','val'],loc='upper left')
plt.show()

# %%
pd.DataFrame(best_mlp_model.history_).plot(figsize=(8,5))
plt.show()

# %%
predictions=best_mlp_model.predict(X_test_s)
# Out:
# 64/64 [==============================] - 0s 5ms/step

# %%
predictions_ann = predictions.reshape(predictions.shape[0],1)

# %%
predictions_ann[:5]
# Out:
# array([[0.36543748],
#        [0.6761302 ],
#        [0.86441135],
#        [0.626767  ],
#        [0.19511878]], dtype=float32)

# %%
predictions_ann_unscaled = scaler_y.inverse_transform(predictions_ann)

# %%
predictions_ann_unscaled[:5]
# Out:
# array([[0.36543748],
#        [0.6761302 ],
#        [0.86441135],
#        [0.626767  ],
#        [0.19511878]], dtype=float32)

# %%
y_test_unscaled=scaler_y.inverse_transform(y_test_s)

# %%
print(f'MAE: {mean_absolute_error(y_test_unscaled, predictions_ann)}')
print(f'MSE: {mean_squared_error(y_test_unscaled, predictions_ann)}')
print(f'RMSE: {np.sqrt(metrics.mean_squared_error(y_test_unscaled, predictions_ann))}')
# Out:
# MAE: 0.0489675449763999
# MSE: 0.0038331474462906493
# RMSE: 0.06191241754519564

# %%
plt.scatter(y_test_unscaled,predictions_ann)

# %%
def real_predicted_viz(limit):
    plt.figure(figsize=(14,6))
    plt.plot(y_test_unscaled[:limit],color='green',label='Actual')
    plt.plot(predictions_ann_unscaled[:limit],color='red',label='Predicted')
    plt.grid(alpha=0.3)
    plt.xlabel('Houses')
    plt.ylabel('Price')
    plt.title('Real vs Predicted')
    plt.legend()
    plt.show()

# %%
real_predicted_viz(200)

# %% [markdown]
# ### GradientBoosting

# %%
param_boost = {'learning_rate': [0.01,0.02,0.03],'subsample': [0.1, 0.2, 0.4],'n_estimators' : [128,256,512],'max_depth': [4,8,12]}

# %%
estimator_boost=GradientBoostingRegressor()
grid_boost=GridSearchCV(estimator_boost,param_boost,refit=True,verbose=0)

# %%
grid_boost.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.02, 0.03],
#                          'max_depth': [4, 8, 12],
#                          'n_estimators': [128, 256, 512],
#                          'subsample': [0.1, 0.2, 0.4]})

# %%
grid_boost.best_params_
# Out:
# {'learning_rate': 0.03, 'max_depth': 4, 'n_estimators': 512, 'subsample': 0.4}

# %%
boost_score = grid_boost.score(X_test,y_test)

# %%
prediction_boost=grid_boost.predict(X_test)

# %%
plt.xlabel('Dados de teste (y_test)')
plt.ylabel('Previsões (predictions)')
plt.scatter(y_test,prediction_boost)

# %%
print(f'MAE: {mean_absolute_error(y_test, prediction_boost)}')
print(f'MSE: {mean_squared_error(y_test, prediction_boost)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test, prediction_boost))}')
# Out:
# MAE: 0.045492293029560094
# MSE: 0.003299095791622502
# RMSE: 0.05743775580245543
